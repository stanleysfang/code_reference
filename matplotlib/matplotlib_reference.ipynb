# %% [markdown]
# # matplotlib Reference

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path="/home/sfang/windows/gitlab/stanleysfang/code_reference/example_data/"

# %%
train = pd.read_csv(
    data_path + "kaggle_titanic_train.csv",
    header=0, names=['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'ParCh', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
    dtype={"Name": "category", "Sex": "category", "Ticket": "category", "Embarked": "category"}
)

# %% [markdown]
# ### Histogram

# %%
y, x, _ = plt.hist(train["Fare"], range(0, int(train["Fare"].max())+5, 5), facecolor='g')

plt.xlabel("Fare")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Fare")
plt.text(50, 300, "x_max = {x_max}\ny_max = {y_max}".format(x_max=x[list(y).index(y.max())], y_max=int(y.max())))
plt.grid(True)

plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# ### Scatterplot

# %%
plt.scatter(train["Age"], train["Fare"], c='r')

plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Line Chart

# %%
pclass_avg_fare = train[["Pclass", "Fare"]].groupby(["Pclass"]).mean()
pclass = list(pclass_avg_fare.index)
avg_fare = pclass_avg_fare.iloc[:, 0].tolist()

plt.plot(pclass, avg_fare, c='b')

plt.xlabel("Pclass")
plt.ylabel("Avg Fare")
plt.title("Pclass vs Avg Fare")

plt.show()

# %% [markdown]
# ### Time Series Chart

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ### Subplots

# %%
nrows=2
ncols=2
fig, axs = plt.subplots(nrows, ncols, figsize=(13, 10))

#### Ax 1 ####
plt.subplot(nrows, ncols, 1)

y, x, _ = plt.hist(train["Survived"], facecolor='g')

plt.xlabel("Survived")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Survived")
plt.grid(True)

#### Ax 2 ####
plt.subplot(nrows, ncols, 2)

y, x, _ = plt.hist(train["Pclass"], facecolor='g')

plt.xlabel("Pclass")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Pclass")
plt.grid(True)

#### Ax 3 ####
plt.subplot(nrows, ncols, 3)

y, x, _ = plt.hist(train["Age"], range(0, int(train["Age"].max())+5, 5), facecolor='g')

plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Age")
plt.text(0, 100, "x_max = {x_max}\ny_max = {y_max}".format(x_max=x[list(y).index(y.max())], y_max=int(y.max())))
plt.grid(True)

#### Ax 4 ####
plt.subplot(nrows, ncols, 4)

y, x, _ = plt.hist(train["Fare"], range(0, int(train["Fare"].max())+5, 5), facecolor='g')

plt.xlabel("Fare")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Fare")
plt.text(50, 300, "x_max = {x_max}\ny_max = {y_max}".format(x_max=x[list(y).index(y.max())], y_max=int(y.max())))
plt.grid(True)

#### Figure Parameters ####
plt.tight_layout()

plt.show()
